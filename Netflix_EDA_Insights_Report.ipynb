# %% [markdown]
# <a href="https://colab.research.google.com/github/yerramonika2006-cell/Netflix-EDA-Project/blob/main/Netflix_EDA_Insights_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Netflix Movies & TV Shows Dataset Analysis
#
# ## Exploratory Data Analysis (EDA) & Insights Report
#
# **Name:** Yerra Monika
#
# **Tools Used:**
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - Google Colab

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %% [markdown]
# # Step 1: Load and Inspect the Dataset

# %%
df = pd.read_csv("netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#                           date_added  release_year
# count                           8797   8807.000000
# mean   2019-05-17 05:59:08.436967168   2014.180198
# min              2008-01-01 00:00:00   1925.000000
# 25%              2018-04-06 00:00:00   2013.000000
# 50%              2019-07-02 00:00:00   2017.000000
# 75%              2020-08-19 00:00:00   2019.000000
# max              2021-09-25 00:00:00   2021.000000
# std                              NaN      8.819312

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           0
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Dataset Summary
#
# 1. The dataset contains Netflix Movies and TV Shows.
# 2. It includes information about title, cast, director, country, rating, and release year.
# 3. Both Movies and TV Shows are available for analysis.
# 4. Some columns contain missing values.
# 5. The dataset helps identify Netflix content trends.

# %% [markdown]
# # Step 2: Data Cleaning

# %%
df['director'] = df['director'].fillna('Unknown')

# %%
df['cast'] = df['cast'].fillna('Not Available')

# %%
df['country'] = df['country'].fillna('Unknown')

# %%
df['rating'] = df['rating'].fillna(df['rating'].mode()[0])

# %%
df.drop_duplicates(inplace=True)

# %%
df['date_added'] = df['date_added'].str.strip()

df['date_added'] = pd.to_datetime(
    df['date_added'],
    format='%B %d, %Y'
)

# %%
df['date_added'].head()
# Out:
# 0   2021-09-25
# 1   2021-09-24
# 2   2021-09-24
# 3   2021-09-24
# 4   2021-09-24
# Name: date_added, dtype: datetime64[ns]

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           0
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %% [markdown]
# ## Cleaning Decisions
#
# 1. Missing director values were replaced with "Unknown".
# 2. Missing cast values were replaced with "Not Available".
# 3. Missing country values were replaced with "Unknown".
# 4. Missing ratings were replaced using the most frequent rating.
# 5. Duplicate rows were removed.
# 6. Date column was converted to datetime format.

# %% [markdown]
# # Step 3: Exploratory Data Analysis

# %% [markdown]
# ### Question 1:
# Which content type is more common on Netflix?

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %% [markdown]
# ### Question 2:
# Which countries produce the most Netflix content?

# %%
df['country'].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# Unknown            831
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %% [markdown]
# ### Question 3:
# Which release years contain the most titles?

# %%
df['release_year'].value_counts().head(10)
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# Name: count, dtype: int64

# %% [markdown]
# ### Question 4:
# What are the most common content ratings?

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3211
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %% [markdown]
# ### Question 5:
# Who are the top directors on Netflix?

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Unknown                   2634
# Rajiv Chilaka               19
# Raúl Campos, Jan Suter      18
# Suhas Kadav                 16
# Marcus Raboy                16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Martin Scorsese             12
# Youssef Chahine             12
# Jay Chapman                 12
# Name: count, dtype: int64

# %% [markdown]
# # Step 4: Data Visualization

# %% [markdown]
# ### Chart 1: Movies vs TV Shows

# %%
plt.figure(figsize=(8,5))

sns.countplot(data=df, x='type')

plt.title("Movies vs TV Shows")
plt.xlabel("Content Type")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# ### Chart 2: Release Year Distribution

# %%
plt.figure(figsize=(10,5))

plt.hist(df['release_year'], bins=20)

plt.title("Distribution of Release Years")
plt.xlabel("Release Year")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ### Chart 3: Content Distribution

# %%
df['type'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)

plt.title("Movies vs TV Shows Distribution")
plt.ylabel("")

plt.show()

# %% [markdown]
# ### Chart 4: Netflix Content Growth

# %%
year_data = df['release_year'].value_counts().sort_index()

plt.figure(figsize=(12,5))

plt.plot(year_data.index, year_data.values)

plt.title("Netflix Content Growth Over Years")
plt.xlabel("Year")
plt.ylabel("Number of Titles")

plt.show()

# %% [markdown]
# ### Chart 5: Release Year Distribution

# %%
plt.figure(figsize=(10,5))

sns.scatterplot(
    data=df,
    x='release_year',
    y=df.index,
    hue='type'
)

plt.title("Release Year Distribution by Type")

plt.show()

# %% [markdown]
# ### Visualization 6:Year-wise table

# %%
year_type = pd.crosstab(
    df['release_year'],
    df['type']
)

plt.figure(figsize=(12,8))

sns.heatmap(
    year_type,
    cmap='YlGnBu'
)

plt.title("Heatmap of Release Year vs Content Type")

plt.show()

# %% [markdown]
# # Step 5: Insights Report

# %% [markdown]
# ## Business Insights
#
# ### 1.
# Movies constitute a larger share of Netflix content than TV Shows, indicating Netflix's stronger focus on movie distribution.
#
# ### 2.
# The United States contributes the highest amount of content, showing its dominance in Netflix's content library.
#
# ### 3.
# Content production increased significantly after 2015, reflecting Netflix's rapid global expansion.
#
# ### 4.
# TV-MA is the most common content rating, suggesting that Netflix primarily targets mature audiences.
#
# ### 5.
# A small group of directors appears repeatedly, while most directors contribute only a few titles.

# %% [markdown]
# # Most Surprising Finding
#
# The most surprising finding was the dramatic growth in Netflix content after 2015. The number of titles increased rapidly within a short period, highlighting Netflix's aggressive investment in content creation and global expansion.

# %% [markdown]
# # Conclusion
#
# This project explored Netflix Movies and TV Shows using data cleaning, exploratory data analysis, and visualizations. Several trends related to content type, ratings, countries, and release years were identified. The findings provide useful insights into Netflix's content strategy and growth over time.
